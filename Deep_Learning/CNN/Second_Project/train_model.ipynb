# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import os
import pickle

# Dataset path
dataset_path = "Dataset"

# Load dataset
img_size = (128, 128)
batch_size = 32

train_ds = tf.keras.utils.image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=img_size,
    batch_size=batch_size
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=img_size,
    batch_size=batch_size
)

class_names = train_ds.class_names
print("Classes:", class_names)

# Save labels
with open("models/vehicle_labels.pkl", "wb") as f:
    pickle.dump(class_names, f)

# Optimize performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# Model
model = models.Sequential([
    layers.Rescaling(1./255, input_shape=(128,128,3)),
    layers.Conv2D(32, 3, activation='relu'),
    layers.MaxPooling2D(),

    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),

    layers.Conv2D(128, 3, activation='relu'),
    layers.MaxPooling2D(),

    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(len(class_names), activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10
)

# Save model
model.save("models/vehicle_model.keras")

print("Model saved successfully!")
# Out:
# Found 567 files belonging to 6 classes.
# Using 454 files for training.
# Found 567 files belonging to 6 classes.
# Using 113 files for validation.
# Classes: ['2_Wheeler', 'Auto', 'Bus', 'Car', 'Special_Vehicle', 'Truck']
# C:\Users\Deepak Kumar\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\preprocessing\data_layer.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 405ms/step - accuracy: 0.2269 - loss: 1.7804 - val_accuracy: 0.4779 - val_loss: 1.6205
# Epoch 2/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 8s 297ms/step - accuracy: 0.4537 - loss: 1.5142 - val_accuracy: 0.4513 - val_loss: 1.3739
# Epoch 3/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 331ms/step - accuracy: 0.5441 - loss: 1.2230 - val_accuracy: 0.5221 - val_loss: 1.4062
# Epoch 4/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 381ms/step - accuracy: 0.5727 - loss: 1.0813 - val_accuracy: 0.4602 - val_loss: 1.4731
# Epoch 5/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 338ms/step - accuracy: 0.6586 - loss: 0.9420 - val_accuracy: 0.5487 - val_loss: 1.2248
# Epoch 6/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 348ms/step - accuracy: 0.7401 - loss: 0.7355 - val_accuracy: 0.6106 - val_loss: 1.1760
# Epoch 7/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 355ms/step - accuracy: 0.8040 - loss: 0.5884 - val_accuracy: 0.5398 - val_loss: 1.3909
# Epoch 8/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 367ms/step - accuracy: 0.8480 - loss: 0.4721 - val_accuracy: 0.6372 - val_loss: 1.1690
# Epoch 9/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 11s 410ms/step - accuracy: 0.9031 - loss: 0.3487 - val_accuracy: 0.5841 - val_loss: 1.5057
# Epoch 10/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 399ms/step - accuracy: 0.9317 - loss: 0.2305 - val_accuracy: 0.5133 - val_loss: 1.7501
# Model saved successfully!
